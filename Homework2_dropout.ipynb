# %%
# 导入相应的库
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np

import datetime

# %%
# 定义超参数
# 训练批次大小
train_batch_size = 64
# 测试批次大小
test_batch_size = 64
# 学习率
learning_rate = 0.01
# 迭代次数
num_epoches = 100

#动量
momentum = 0

#丢弃率
dropout_rate = 0.1
#判断是否有GPU，如果有则使用GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') 

#标签顺序
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# 定义预处理函数
transform = transforms.Compose([
    #将图像数据转换为张量
    transforms.ToTensor(), 
    #将图像数据归一化到[-1,1]
    #transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    # #随机水平翻转
    # transforms.RandomHorizontalFlip(),
    # #随机遮挡
    # transforms.RandomErasing(scale=(0.04,0.2), ratio=(0.5,2)),
    # #随机裁剪
    # transforms.RandomCrop(32, padding=4)
])  

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
])
#下载数据，并对数据进行预处理
mnist_train= torchvision.datasets.CIFAR10(root='./data', train=True, transform=transform,download=True) 
mnist_test= torchvision.datasets.CIFAR10(root='./data', train=False, transform=transform_test,download=True)
mnist_show= torchvision.datasets.CIFAR10(root='./data', train=False, transform=transforms.ToTensor(),download=False)
#得到一个生成器
train_loader = DataLoader(mnist_train, batch_size=train_batch_size)
test_loader = DataLoader(mnist_test, batch_size=test_batch_size)
show_loader = DataLoader(mnist_show, batch_size=test_batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# 可视化源数据
# 打印测试集数据标签
examples = enumerate(show_loader) #用于将一个可遍历的数据对象(如列表、元组或字符串)组合为一个索引序列，同时列出数据和数据下标

batch_idx, (imgs, labels) = next(examples) #读取数据,batch_idx从0开始
#绘制部分数据图像
fig = plt.figure() #创建一个图像
for i in range(12):
    plt.subplot(3,4,i+1) #3行4列，第i+1个子图
    plt.tight_layout() #自动调整子图参数,使之填充整个图像区域
    plt.imshow(imgs[i].permute(1,2,0), interpolation='none') #绘制图像
    plt.title("Ground Truth: {}".format(classes[labels[i].item()])) #设置标题
    plt.xticks([]) #设置x轴刻度为空
    plt.yticks([]) #设置y轴刻度为空
plt.show() #显示图像
print(labels) #读取标签数据
print(labels.shape) #torch.Size([32])，因为batch_size为32
# Out:
# tensor([3, 8, 8, 0, 6, 6, 1, 6, 3, 1, 0, 9, 5, 7, 9, 8, 5, 7, 8, 6, 7, 0, 4, 9,
#         5, 2, 4, 0, 9, 6, 6, 5, 4, 5, 9, 2, 4, 1, 9, 5, 4, 6, 5, 6, 0, 9, 3, 9,
#         7, 6, 9, 8, 0, 3, 8, 8, 7, 7, 4, 6, 7, 3, 6, 3])
# torch.Size([64])

# %%
# 构建模型
class Net(nn.Module):
    # """
    # 使用sequential构建网络，Sequential()函数的功能是将网络的层组合到一起
    # """
    def __init__(self):
        super(Net, self).__init__()
        self.model = nn.Sequential(
            #lenet-5
            nn.Conv2d(3, 32, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 32, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Flatten(),
            nn.Linear(64*4*4, 64),
            #dropout
            nn.Dropout(p = 0.5,inplace = True),
            # 激活函数
            nn.ReLU(True),
            #新增的隐藏层
            # nn.Linear(256, 64),
            # 激活函数
            # nn.ReLU(True),
            nn.Linear(64, 10),
            nn.ReLU(True),
        )
    def forward(self, x):
        x = self.model(x)
        return x
    
#创建模型实例
model = Net().to(device)
# 损失函数
criterion = nn.CrossEntropyLoss().to(device)
# 优化器
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum)
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.99))
# 其他几种优化算法：
# opt_SGD = torch.optim.SGD(net_SGD.parameters(), lr=LR)
# opt_Momentum = torch.optim.SGD(net_Momentum.parameters(), lr=LR, momentum=0.9)
# opt_RMSProp = torch.optim.RMSprop(net_RMSProp.parameters(), lr=LR, alpha=0.9)
# opt_Adam = torch.optim.Adam(net_Adam.parameters(), lr=LR, betas=(0.9, 0.99))

# %%
# 训练模型并绘制Loss函数曲线
print('start training')
iterations = 0
#记录数据
losses = []
acces = []
eval_losses = []
eval_acces = []

#开始计时
start = datetime.datetime.now()

for epoch in range(num_epoches):
    train_loss = 0
    train_acc = 0
    model.train()
    #动态修改学习率
    if epoch%5==0:
        optimizer.param_groups[0]['lr']*=0.9
        print('lr is set to {}'.format(optimizer.param_groups[0]['lr']))
    for img,label in train_loader:
        img,label = img.to(device),label.to(device)
        #前向传播
        out = model(img)
        #计算损失
        loss = criterion(out,label)
        #反向传播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #记录误差
        train_loss += loss.item()
        #计算准确率
        _,pred = torch.max(out,1)
        num_correct = (pred == label).sum().item()
        acc = num_correct/img.shape[0]
        train_acc += acc
    losses.append(train_loss/len(train_loader))
    acces.append(train_acc/len(train_loader))
    #在测试集上测试
    eval_loss = 0
    eval_acc = 0

    model.eval()
    for img,label in test_loader:
        img,label = img.to(device),label.to(device)
        out = model(img)
        loss = criterion(out,label)
        #记录误差
        eval_loss += loss.item()
        #计算准确率
        _,pred = torch.max(out,1)
        num_correct = (pred == label).sum().item()
        acc = num_correct/img.shape[0]
        eval_acc += acc
    eval_losses.append(eval_loss/len(test_loader))
    eval_acces.append(eval_acc/len(test_loader))
    print('epoch: {}, Train Loss: {:.6f}, Train Acc: {:.6f}, Test Loss: {:.6f}, Test Acc: {:.6f}'
          .format(epoch, train_loss/len(train_loader), train_acc/len(train_loader), 
                  eval_loss/len(test_loader), eval_acc/len(test_loader)))
#结束计时
end = datetime.datetime.now()
# 绘制损失函数曲线
plt.title('train loss')
plt.plot(np.arange(len(losses)), losses, "blue", label="Training Loss")
plt.plot(np.arange(len(eval_losses)), eval_losses, "red", label="Test Loss")
plt.xlim([0,epoch])
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend(['Train Loss', 'Test Loss'], loc='upper right')
plt.savefig('./loss_dropout.png')
# 计算训练时间
print('time used: ', end-start)
torch.save(model,'./model/model_dropout.ckpt')
# Out:
# start training
# lr is set to 0.009000000000000001
# epoch: 0, Train Loss: 2.100356, Train Acc: 0.241548, Test Loss: 1.905605, Test Acc: 0.336783
# epoch: 1, Train Loss: 1.796872, Train Acc: 0.359974, Test Loss: 1.614526, Test Acc: 0.423169
# epoch: 2, Train Loss: 1.627636, Train Acc: 0.415301, Test Loss: 1.512971, Test Acc: 0.455215
# epoch: 3, Train Loss: 1.520023, Train Acc: 0.457581, Test Loss: 1.419452, Test Acc: 0.487261
# epoch: 4, Train Loss: 1.439125, Train Acc: 0.483636, Test Loss: 1.308872, Test Acc: 0.534037
# lr is set to 0.008100000000000001
# epoch: 5, Train Loss: 1.366526, Train Acc: 0.512008, Test Loss: 1.308629, Test Acc: 0.527966
# epoch: 6, Train Loss: 1.320312, Train Acc: 0.531210, Test Loss: 1.260853, Test Acc: 0.543889
# epoch: 7, Train Loss: 1.269851, Train Acc: 0.547554, Test Loss: 1.138468, Test Acc: 0.599821
# epoch: 8, Train Loss: 1.223440, Train Acc: 0.565357, Test Loss: 1.126591, Test Acc: 0.601712
# epoch: 9, Train Loss: 1.186986, Train Acc: 0.578105, Test Loss: 1.126011, Test Acc: 0.597930
# lr is set to 0.007290000000000001
# epoch: 10, Train Loss: 1.147591, Train Acc: 0.592271, Test Loss: 1.039182, Test Acc: 0.634355
# epoch: 11, Train Loss: 1.120160, Train Acc: 0.602841, Test Loss: 1.042606, Test Acc: 0.630673
# epoch: 12, Train Loss: 1.091392, Train Acc: 0.613451, Test Loss: 1.024951, Test Acc: 0.638734
# epoch: 13, Train Loss: 1.063796, Train Acc: 0.625559, Test Loss: 1.004685, Test Acc: 0.646298
# epoch: 14, Train Loss: 1.042215, Train Acc: 0.632353, Test Loss: 0.970436, Test Acc: 0.656449
# lr is set to 0.006561000000000002
# epoch: 15, Train Loss: 1.018238, Train Acc: 0.640585, Test Loss: 0.962121, Test Acc: 0.659833
# epoch: 16, Train Loss: 0.989540, Train Acc: 0.650595, Test Loss: 1.031195, Test Acc: 0.638834
# epoch: 17, Train Loss: 0.977410, Train Acc: 0.655411, Test Loss: 0.931478, Test Acc: 0.676553
# epoch: 18, Train Loss: 0.958778, Train Acc: 0.663763, Test Loss: 0.927686, Test Acc: 0.674463
# epoch: 19, Train Loss: 0.938229, Train Acc: 0.671156, Test Loss: 0.920260, Test Acc: 0.679439
# lr is set to 0.005904900000000002
# epoch: 20, Train Loss: 0.915262, Train Acc: 0.677769, Test Loss: 0.965049, Test Acc: 0.667297
# epoch: 21, Train Loss: 0.904271, Train Acc: 0.683384, Test Loss: 0.903384, Test Acc: 0.684813
# epoch: 22, Train Loss: 0.887463, Train Acc: 0.688759, Test Loss: 0.956597, Test Acc: 0.667098
# epoch: 23, Train Loss: 0.876394, Train Acc: 0.691296, Test Loss: 0.909684, Test Acc: 0.685111
# epoch: 24, Train Loss: 0.860887, Train Acc: 0.695153, Test Loss: 0.895060, Test Acc: 0.690784
# lr is set to 0.005314410000000002
# epoch: 25, Train Loss: 0.842095, Train Acc: 0.705902, Test Loss: 0.961426, Test Acc: 0.669486
# epoch: 26, Train Loss: 0.826839, Train Acc: 0.709579, Test Loss: 0.863146, Test Acc: 0.700139
# epoch: 27, Train Loss: 0.819728, Train Acc: 0.711917, Test Loss: 0.945982, Test Acc: 0.674463
# epoch: 28, Train Loss: 0.803198, Train Acc: 0.715253, Test Loss: 0.859695, Test Acc: 0.702130
# epoch: 29, Train Loss: 0.801686, Train Acc: 0.717092, Test Loss: 0.870969, Test Acc: 0.695760
# lr is set to 0.004782969000000002
# epoch: 30, Train Loss: 0.782032, Train Acc: 0.723426, Test Loss: 0.868786, Test Acc: 0.701931
# epoch: 31, Train Loss: 0.765702, Train Acc: 0.730599, Test Loss: 0.856932, Test Acc: 0.706608
# epoch: 32, Train Loss: 0.756293, Train Acc: 0.733935, Test Loss: 0.893323, Test Acc: 0.695760
# epoch: 33, Train Loss: 0.746080, Train Acc: 0.737632, Test Loss: 0.872218, Test Acc: 0.708101
# epoch: 34, Train Loss: 0.745119, Train Acc: 0.736713, Test Loss: 0.850882, Test Acc: 0.711982
# lr is set to 0.004304672100000002
# epoch: 35, Train Loss: 0.722640, Train Acc: 0.745984, Test Loss: 0.876060, Test Acc: 0.705215
# epoch: 36, Train Loss: 0.714040, Train Acc: 0.748441, Test Loss: 0.882896, Test Acc: 0.702926
# epoch: 37, Train Loss: 0.708411, Train Acc: 0.749700, Test Loss: 0.864847, Test Acc: 0.708798
# epoch: 38, Train Loss: 0.698702, Train Acc: 0.752338, Test Loss: 0.857552, Test Acc: 0.713077
# epoch: 39, Train Loss: 0.693372, Train Acc: 0.751818, Test Loss: 0.900356, Test Acc: 0.700338
# lr is set to 0.003874204890000002
# epoch: 40, Train Loss: 0.677410, Train Acc: 0.758812, Test Loss: 0.880103, Test Acc: 0.706608
# epoch: 41, Train Loss: 0.665597, Train Acc: 0.762708, Test Loss: 0.869560, Test Acc: 0.710490
# epoch: 42, Train Loss: 0.662319, Train Acc: 0.764526, Test Loss: 0.889130, Test Acc: 0.706011
# epoch: 43, Train Loss: 0.656693, Train Acc: 0.764686, Test Loss: 0.858044, Test Acc: 0.716262
# epoch: 44, Train Loss: 0.647260, Train Acc: 0.766484, Test Loss: 0.877328, Test Acc: 0.710788
# lr is set to 0.003486784401000002
# epoch: 45, Train Loss: 0.634121, Train Acc: 0.773278, Test Loss: 0.907584, Test Acc: 0.707504
# epoch: 46, Train Loss: 0.628960, Train Acc: 0.775815, Test Loss: 0.868549, Test Acc: 0.715167
# epoch: 47, Train Loss: 0.619277, Train Acc: 0.778832, Test Loss: 0.870479, Test Acc: 0.717954
# epoch: 48, Train Loss: 0.613221, Train Acc: 0.780351, Test Loss: 0.876431, Test Acc: 0.713674
# epoch: 49, Train Loss: 0.609263, Train Acc: 0.782149, Test Loss: 0.906040, Test Acc: 0.715764
# lr is set to 0.003138105960900002
# epoch: 50, Train Loss: 0.599179, Train Acc: 0.784847, Test Loss: 0.933097, Test Acc: 0.702428
# epoch: 51, Train Loss: 0.591067, Train Acc: 0.786925, Test Loss: 0.880129, Test Acc: 0.716561
# epoch: 52, Train Loss: 0.580039, Train Acc: 0.792579, Test Loss: 0.880630, Test Acc: 0.717058
# epoch: 53, Train Loss: 0.579355, Train Acc: 0.792499, Test Loss: 0.896886, Test Acc: 0.717357
# epoch: 54, Train Loss: 0.572816, Train Acc: 0.792619, Test Loss: 0.895275, Test Acc: 0.717755
# lr is set to 0.0028242953648100018
# epoch: 55, Train Loss: 0.561863, Train Acc: 0.795616, Test Loss: 0.897398, Test Acc: 0.718252
# epoch: 56, Train Loss: 0.554551, Train Acc: 0.801111, Test Loss: 0.880329, Test Acc: 0.719347
# epoch: 57, Train Loss: 0.549809, Train Acc: 0.802570, Test Loss: 0.902283, Test Acc: 0.715565
# epoch: 58, Train Loss: 0.548861, Train Acc: 0.802270, Test Loss: 0.892404, Test Acc: 0.720541
# epoch: 59, Train Loss: 0.539396, Train Acc: 0.804528, Test Loss: 0.912840, Test Acc: 0.716760
# lr is set to 0.0025418658283290017
# epoch: 60, Train Loss: 0.533964, Train Acc: 0.806526, Test Loss: 0.896201, Test Acc: 0.719148
# epoch: 61, Train Loss: 0.527995, Train Acc: 0.809403, Test Loss: 0.916438, Test Acc: 0.715665
# epoch: 62, Train Loss: 0.525092, Train Acc: 0.808784, Test Loss: 0.924350, Test Acc: 0.716162
# epoch: 63, Train Loss: 0.517694, Train Acc: 0.811461, Test Loss: 0.911265, Test Acc: 0.716561
# epoch: 64, Train Loss: 0.513836, Train Acc: 0.812340, Test Loss: 0.933755, Test Acc: 0.718850
# lr is set to 0.0022876792454961017
# epoch: 65, Train Loss: 0.505462, Train Acc: 0.816536, Test Loss: 0.917407, Test Acc: 0.718850
# epoch: 66, Train Loss: 0.502040, Train Acc: 0.815977, Test Loss: 0.948938, Test Acc: 0.713276
# epoch: 67, Train Loss: 0.496628, Train Acc: 0.819793, Test Loss: 0.939466, Test Acc: 0.716660
# epoch: 68, Train Loss: 0.492079, Train Acc: 0.818574, Test Loss: 0.960750, Test Acc: 0.715864
# epoch: 69, Train Loss: 0.490233, Train Acc: 0.820852, Test Loss: 0.951893, Test Acc: 0.715466
# lr is set to 0.0020589113209464917
# epoch: 70, Train Loss: 0.480482, Train Acc: 0.827026, Test Loss: 0.946895, Test Acc: 0.718551
# epoch: 71, Train Loss: 0.480218, Train Acc: 0.823789, Test Loss: 0.973789, Test Acc: 0.715665
# epoch: 72, Train Loss: 0.473512, Train Acc: 0.826926, Test Loss: 0.958872, Test Acc: 0.718153
# epoch: 73, Train Loss: 0.472870, Train Acc: 0.825827, Test Loss: 0.966496, Test Acc: 0.715864
# epoch: 74, Train Loss: 0.466040, Train Acc: 0.830523, Test Loss: 0.978941, Test Acc: 0.718650
# lr is set to 0.0018530201888518425
# epoch: 75, Train Loss: 0.462478, Train Acc: 0.829763, Test Loss: 0.974635, Test Acc: 0.718352
# epoch: 76, Train Loss: 0.460043, Train Acc: 0.830223, Test Loss: 0.968566, Test Acc: 0.716959
# epoch: 77, Train Loss: 0.457189, Train Acc: 0.832541, Test Loss: 0.963917, Test Acc: 0.719447
# epoch: 78, Train Loss: 0.452138, Train Acc: 0.833220, Test Loss: 0.978239, Test Acc: 0.717655
# epoch: 79, Train Loss: 0.447698, Train Acc: 0.836117, Test Loss: 0.983818, Test Acc: 0.718352
# lr is set to 0.0016677181699666583
# epoch: 80, Train Loss: 0.438958, Train Acc: 0.839474, Test Loss: 0.977376, Test Acc: 0.719248
# epoch: 81, Train Loss: 0.439541, Train Acc: 0.836937, Test Loss: 0.998974, Test Acc: 0.718053
# epoch: 82, Train Loss: 0.436562, Train Acc: 0.841772, Test Loss: 0.985910, Test Acc: 0.720641
# epoch: 83, Train Loss: 0.432280, Train Acc: 0.840673, Test Loss: 0.997466, Test Acc: 0.719546
# epoch: 84, Train Loss: 0.428918, Train Acc: 0.842072, Test Loss: 0.995769, Test Acc: 0.719347
# lr is set to 0.0015009463529699924
# epoch: 85, Train Loss: 0.421415, Train Acc: 0.844649, Test Loss: 1.005337, Test Acc: 0.718451
# epoch: 86, Train Loss: 0.424117, Train Acc: 0.843990, Test Loss: 1.001942, Test Acc: 0.720442
# epoch: 87, Train Loss: 0.421702, Train Acc: 0.842771, Test Loss: 1.017538, Test Acc: 0.720641
# epoch: 88, Train Loss: 0.415603, Train Acc: 0.844629, Test Loss: 1.016316, Test Acc: 0.720641
# epoch: 89, Train Loss: 0.414046, Train Acc: 0.846787, Test Loss: 1.024803, Test Acc: 0.719546
# lr is set to 0.0013508517176729932
# epoch: 90, Train Loss: 0.409582, Train Acc: 0.847686, Test Loss: 1.012147, Test Acc: 0.720541
# epoch: 91, Train Loss: 0.409261, Train Acc: 0.849365, Test Loss: 1.033579, Test Acc: 0.718352
# epoch: 92, Train Loss: 0.405545, Train Acc: 0.849445, Test Loss: 1.024874, Test Acc: 0.720442
# epoch: 93, Train Loss: 0.403588, Train Acc: 0.850823, Test Loss: 1.027215, Test Acc: 0.721636
# epoch: 94, Train Loss: 0.396591, Train Acc: 0.851822, Test Loss: 1.027474, Test Acc: 0.722930
# lr is set to 0.001215766545905694
# epoch: 95, Train Loss: 0.399748, Train Acc: 0.853141, Test Loss: 1.029761, Test Acc: 0.717655
# epoch: 96, Train Loss: 0.395241, Train Acc: 0.852382, Test Loss: 1.049346, Test Acc: 0.720044
# epoch: 97, Train Loss: 0.392680, Train Acc: 0.855858, Test Loss: 1.034541, Test Acc: 0.721338
# epoch: 98, Train Loss: 0.387228, Train Acc: 0.856897, Test Loss: 1.045358, Test Acc: 0.717257
# epoch: 99, Train Loss: 0.386868, Train Acc: 0.856797, Test Loss: 1.051436, Test Acc: 0.719845
# time used:  0:37:01.041500

# %%
# 测试模型在一个或数个batch的分类情况，并输出图像及对应预测名称，打印正确率
print('start testing')
#加载模型
model_test = torch.load('./model/model_dropout.ckpt')
#设置模型为评估模式
model_test.eval()
#设置测试集
mytest = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transforms.ToTensor(),download=True)
mytest_loader = torch.utils.data.DataLoader(mytest, batch_size=test_batch_size, shuffle=True)
#归一化
test_transform = transforms.Compose([
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    # transforms.ToPILImage()
])
eval_loss = 0
eval_acc = 0
fig = plt.figure()
#batch 循环
for i,(img,label) in enumerate(mytest_loader):
    img,label = img.to(device),label.to(device)
    test_img = img
    img = test_transform(img)
    out = model_test(img)
    loss = criterion(out,label)
    #记录误差
    eval_loss += loss.data.item()*label.size(0)
    #计算准确率
    _,pred = torch.max(out,1)
    num_correct = (pred == label).sum().item()
    eval_acc += num_correct

    #绘制图片（归一化后）
    if i == 0:
        for j in range(6):
            plt.subplot(2,3,j+1)
            plt.tight_layout()
            plt.imshow(test_img[j].permute(1,2,0), interpolation='none')
            plt.title('Prediction: {}'.format(classes[pred[j].item()]))
            plt.xticks([])
            plt.yticks([])
plt.show()
print('Test Loss: {:.6f}, Test Acc: {:.6f}'.format(eval_loss/len(mytest), eval_acc/len(mytest)))
# Out:
# start testing
# C:\Users\Darwin_\AppData\Local\Temp\ipykernel_4700\2625516751.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_test = torch.load('./model/model_dropout.ckpt')
# Files already downloaded and verified
# Test Loss: 1.048531, Test Acc: 0.720300
