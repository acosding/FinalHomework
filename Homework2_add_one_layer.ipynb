# %%
# 导入相应的库
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np

import datetime

# %%
# 定义超参数
# 训练批次大小
train_batch_size = 64
# 测试批次大小
test_batch_size = 64
# 学习率
learning_rate = 0.01
# 迭代次数
num_epoches = 100

#动量
momentum = 0

#丢弃率
dropout_rate = 0.5
#判断是否有GPU，如果有则使用GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') 

#标签顺序
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# 定义预处理函数
transform = transforms.Compose([
    #将图像数据转换为张量
    transforms.ToTensor(), 
    #将图像数据归一化到[-1,1]
    #transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    # #随机水平翻转
    # transforms.RandomHorizontalFlip(),
    # #随机遮挡
    # transforms.RandomErasing(scale=(0.04,0.2), ratio=(0.5,2)),
    # #随机裁剪
    # transforms.RandomCrop(32, padding=4)
])  

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
])
#下载数据，并对数据进行预处理
mnist_train= torchvision.datasets.CIFAR10(root='./data', train=True, transform=transform,download=True) 
mnist_test= torchvision.datasets.CIFAR10(root='./data', train=False, transform=transform_test,download=True)
mnist_show= torchvision.datasets.CIFAR10(root='./data', train=False, transform=transforms.ToTensor(),download=False)
#得到一个生成器
train_loader = DataLoader(mnist_train, batch_size=train_batch_size, shuffle=True)
test_loader = DataLoader(mnist_test, batch_size=test_batch_size)
show_loader = DataLoader(mnist_show, batch_size=test_batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# 可视化源数据
# 打印测试集数据标签
examples = enumerate(show_loader) #用于将一个可遍历的数据对象(如列表、元组或字符串)组合为一个索引序列，同时列出数据和数据下标

batch_idx, (imgs, labels) = next(examples) #读取数据,batch_idx从0开始
#绘制部分数据图像
fig = plt.figure() #创建一个图像
for i in range(12):
    plt.subplot(3,4,i+1) #3行4列，第i+1个子图
    plt.tight_layout() #自动调整子图参数,使之填充整个图像区域
    plt.imshow(imgs[i].permute(1,2,0), interpolation='none') #绘制图像
    plt.title("Ground Truth: {}".format(classes[labels[i].item()])) #设置标题
    plt.xticks([]) #设置x轴刻度为空
    plt.yticks([]) #设置y轴刻度为空
plt.show() #显示图像
print(labels) #读取标签数据
print(labels.shape) #torch.Size([32])，因为batch_size为32
# Out:
# tensor([3, 8, 8, 0, 6, 6, 1, 6, 3, 1, 0, 9, 5, 7, 9, 8, 5, 7, 8, 6, 7, 0, 4, 9,
#         5, 2, 4, 0, 9, 6, 6, 5, 4, 5, 9, 2, 4, 1, 9, 5, 4, 6, 5, 6, 0, 9, 3, 9,
#         7, 6, 9, 8, 0, 3, 8, 8, 7, 7, 4, 6, 7, 3, 6, 3])
# torch.Size([64])

# %%
# 构建模型
class Net(nn.Module):
    # """
    # 使用sequential构建网络，Sequential()函数的功能是将网络的层组合到一起
    # """
    def __init__(self):
        super(Net, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 32, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 32, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Flatten(),
            nn.Linear(64*4*4, 256),
            # 激活函数
            nn.ReLU(True),
            #新增的隐藏层
            nn.Linear(256, 64),
            # 激活函数
            nn.ReLU(True),
            nn.Linear(64, 10),
            nn.ReLU(True),
        )
    def forward(self, x):
        x = self.model(x)
        return x
    
#创建模型实例
model = Net().to(device)
# 损失函数
criterion = nn.CrossEntropyLoss().to(device)
# 优化器
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum)
# 其他几种优化算法：
# opt_SGD = torch.optim.SGD(net_SGD.parameters(), lr=LR)
# opt_Momentum = torch.optim.SGD(net_Momentum.parameters(), lr=LR, momentum=0.9)
# opt_RMSProp = torch.optim.RMSprop(net_RMSProp.parameters(), lr=LR, alpha=0.9)
# opt_Adam = torch.optim.Adam(net_Adam.parameters(), lr=LR, betas=(0.9, 0.99))

# %%
# 训练模型并绘制Loss函数曲线
print('start training')
iterations = 0
#记录数据
losses = []
acces = []
eval_losses = []
eval_acces = []

#开始计时
start = datetime.datetime.now()

for epoch in range(num_epoches):
    train_loss = 0
    train_acc = 0
    model.train()
    #动态修改学习率
    if epoch%5==0:
        optimizer.param_groups[0]['lr']*=0.9
        print('lr is set to {}'.format(optimizer.param_groups[0]['lr']))
    for img,label in train_loader:
        img,label = img.to(device),label.to(device)
        #前向传播
        out = model(img)
        #计算损失
        loss = criterion(out,label)
        #反向传播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #记录误差
        train_loss += loss.item()
        #计算准确率
        _,pred = torch.max(out,1)
        num_correct = (pred == label).sum().item()
        acc = num_correct/img.shape[0]
        train_acc += acc
    losses.append(train_loss/len(train_loader))
    acces.append(train_acc/len(train_loader))
    #在测试集上测试
    eval_loss = 0
    eval_acc = 0

    model.eval()
    for img,label in test_loader:
        img,label = img.to(device),label.to(device)
        out = model(img)
        loss = criterion(out,label)
        #记录误差
        eval_loss += loss.item()
        #计算准确率
        _,pred = torch.max(out,1)
        num_correct = (pred == label).sum().item()
        acc = num_correct/img.shape[0]
        eval_acc += acc
    eval_losses.append(eval_loss/len(test_loader))
    eval_acces.append(eval_acc/len(test_loader))
    print('epoch: {}, Train Loss: {:.6f}, Train Acc: {:.6f}, Test Loss: {:.6f}, Test Acc: {:.6f}'
          .format(epoch, train_loss/len(train_loader), train_acc/len(train_loader), 
                  eval_loss/len(test_loader), eval_acc/len(test_loader)))
#结束计时
end = datetime.datetime.now()
# 绘制损失函数曲线
plt.title('train loss')
plt.plot(np.arange(len(losses)), losses, "blue", label="Training Loss")
plt.plot(np.arange(len(eval_losses)), eval_losses, "red", label="Test Loss")
plt.xlim([0,epoch])
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend(['Train Loss', 'Test Loss'], loc='upper right')
plt.savefig('./loss_addol.png')
# 计算训练时间
print('time used: ', end-start)
torch.save(model,'./model/model_addol.ckpt')
# Out:
# start training
# lr is set to 0.009000000000000001
# epoch: 0, Train Loss: 2.148944, Train Acc: 0.216212, Test Loss: 1.934696, Test Acc: 0.296775
# epoch: 1, Train Loss: 1.743211, Train Acc: 0.379995, Test Loss: 1.629827, Test Acc: 0.412122
# epoch: 2, Train Loss: 1.516572, Train Acc: 0.462616, Test Loss: 1.501894, Test Acc: 0.460490
# epoch: 3, Train Loss: 1.376371, Train Acc: 0.513827, Test Loss: 1.393942, Test Acc: 0.500398
# epoch: 4, Train Loss: 1.267672, Train Acc: 0.553309, Test Loss: 1.286576, Test Acc: 0.540307
# lr is set to 0.008100000000000001
# epoch: 5, Train Loss: 1.165455, Train Acc: 0.591392, Test Loss: 1.178245, Test Acc: 0.582006
# epoch: 6, Train Loss: 1.090194, Train Acc: 0.617227, Test Loss: 1.208735, Test Acc: 0.574244
# epoch: 7, Train Loss: 1.023124, Train Acc: 0.641324, Test Loss: 1.073281, Test Acc: 0.619526
# epoch: 8, Train Loss: 0.961491, Train Acc: 0.661825, Test Loss: 1.053412, Test Acc: 0.624403
# epoch: 9, Train Loss: 0.907537, Train Acc: 0.683784, Test Loss: 1.018599, Test Acc: 0.641521
# lr is set to 0.007290000000000001
# epoch: 10, Train Loss: 0.845559, Train Acc: 0.705043, Test Loss: 1.033467, Test Acc: 0.639530
# epoch: 11, Train Loss: 0.797318, Train Acc: 0.721148, Test Loss: 0.961245, Test Acc: 0.666401
# epoch: 12, Train Loss: 0.753795, Train Acc: 0.736173, Test Loss: 1.135887, Test Acc: 0.617038
# epoch: 13, Train Loss: 0.712660, Train Acc: 0.749620, Test Loss: 0.932710, Test Acc: 0.676453
# epoch: 14, Train Loss: 0.670416, Train Acc: 0.765245, Test Loss: 0.935928, Test Acc: 0.675657
# lr is set to 0.006561000000000002
# epoch: 15, Train Loss: 0.617285, Train Acc: 0.784467, Test Loss: 0.934112, Test Acc: 0.683420
# epoch: 16, Train Loss: 0.582646, Train Acc: 0.798094, Test Loss: 0.978909, Test Acc: 0.678842
# epoch: 17, Train Loss: 0.548480, Train Acc: 0.810482, Test Loss: 1.012880, Test Acc: 0.669686
# epoch: 18, Train Loss: 0.511895, Train Acc: 0.822131, Test Loss: 1.028685, Test Acc: 0.674064
# epoch: 19, Train Loss: 0.478886, Train Acc: 0.832261, Test Loss: 0.941372, Test Acc: 0.701931
# lr is set to 0.005904900000000002
# epoch: 20, Train Loss: 0.431524, Train Acc: 0.851063, Test Loss: 1.045084, Test Acc: 0.676951
# epoch: 21, Train Loss: 0.398536, Train Acc: 0.862832, Test Loss: 1.125080, Test Acc: 0.673467
# epoch: 22, Train Loss: 0.369032, Train Acc: 0.872822, Test Loss: 1.001954, Test Acc: 0.705514
# epoch: 23, Train Loss: 0.339467, Train Acc: 0.882313, Test Loss: 1.162729, Test Acc: 0.668690
# epoch: 24, Train Loss: 0.307739, Train Acc: 0.896100, Test Loss: 1.332058, Test Acc: 0.654857
# lr is set to 0.005314410000000002
# epoch: 25, Train Loss: 0.267228, Train Acc: 0.909707, Test Loss: 1.190547, Test Acc: 0.690486
# epoch: 26, Train Loss: 0.241310, Train Acc: 0.919717, Test Loss: 1.191203, Test Acc: 0.691580
# epoch: 27, Train Loss: 0.214577, Train Acc: 0.928848, Test Loss: 1.275534, Test Acc: 0.693869
# epoch: 28, Train Loss: 0.191256, Train Acc: 0.936481, Test Loss: 1.486756, Test Acc: 0.666899
# epoch: 29, Train Loss: 0.172389, Train Acc: 0.944094, Test Loss: 1.522161, Test Acc: 0.670780
# lr is set to 0.004782969000000002
# epoch: 30, Train Loss: 0.135178, Train Acc: 0.959319, Test Loss: 1.406322, Test Acc: 0.696258
# epoch: 31, Train Loss: 0.111973, Train Acc: 0.967771, Test Loss: 1.464751, Test Acc: 0.699940
# epoch: 32, Train Loss: 0.095869, Train Acc: 0.972866, Test Loss: 1.766163, Test Acc: 0.676652
# epoch: 33, Train Loss: 0.081839, Train Acc: 0.978221, Test Loss: 1.769928, Test Acc: 0.673368
# epoch: 34, Train Loss: 0.065407, Train Acc: 0.984895, Test Loss: 1.664537, Test Acc: 0.697154
# lr is set to 0.004304672100000002
# epoch: 35, Train Loss: 0.043068, Train Acc: 0.993167, Test Loss: 1.701906, Test Acc: 0.702030
# epoch: 36, Train Loss: 0.031768, Train Acc: 0.996064, Test Loss: 2.041516, Test Acc: 0.672373
# epoch: 37, Train Loss: 0.027885, Train Acc: 0.996423, Test Loss: 1.842391, Test Acc: 0.701831
# epoch: 38, Train Loss: 0.019252, Train Acc: 0.998681, Test Loss: 1.895933, Test Acc: 0.703324
# epoch: 39, Train Loss: 0.014997, Train Acc: 0.999241, Test Loss: 1.940880, Test Acc: 0.701831
# lr is set to 0.003874204890000002
# epoch: 40, Train Loss: 0.011955, Train Acc: 0.999540, Test Loss: 1.986322, Test Acc: 0.701931
# epoch: 41, Train Loss: 0.010298, Train Acc: 0.999620, Test Loss: 2.013880, Test Acc: 0.701931
# epoch: 42, Train Loss: 0.009233, Train Acc: 0.999680, Test Loss: 2.049729, Test Acc: 0.700836
# epoch: 43, Train Loss: 0.008357, Train Acc: 0.999720, Test Loss: 2.085156, Test Acc: 0.704717
# epoch: 44, Train Loss: 0.007643, Train Acc: 0.999760, Test Loss: 2.114931, Test Acc: 0.702329
# lr is set to 0.003486784401000002
# epoch: 45, Train Loss: 0.006988, Train Acc: 0.999760, Test Loss: 2.131900, Test Acc: 0.703822
# epoch: 46, Train Loss: 0.006557, Train Acc: 0.999760, Test Loss: 2.157254, Test Acc: 0.703424
# epoch: 47, Train Loss: 0.006158, Train Acc: 0.999760, Test Loss: 2.174459, Test Acc: 0.703722
# epoch: 48, Train Loss: 0.005768, Train Acc: 0.999760, Test Loss: 2.205154, Test Acc: 0.701931
# epoch: 49, Train Loss: 0.005473, Train Acc: 0.999760, Test Loss: 2.221168, Test Acc: 0.702030
# lr is set to 0.003138105960900002
# epoch: 50, Train Loss: 0.005105, Train Acc: 0.999780, Test Loss: 2.241187, Test Acc: 0.702428
# epoch: 51, Train Loss: 0.004811, Train Acc: 0.999800, Test Loss: 2.258970, Test Acc: 0.702727
# epoch: 52, Train Loss: 0.004585, Train Acc: 0.999800, Test Loss: 2.275210, Test Acc: 0.702428
# epoch: 53, Train Loss: 0.004424, Train Acc: 0.999800, Test Loss: 2.285212, Test Acc: 0.701831
# epoch: 54, Train Loss: 0.004169, Train Acc: 0.999800, Test Loss: 2.305824, Test Acc: 0.702528
# lr is set to 0.0028242953648100018
# epoch: 55, Train Loss: 0.003953, Train Acc: 0.999820, Test Loss: 2.316780, Test Acc: 0.702329
# epoch: 56, Train Loss: 0.003803, Train Acc: 0.999820, Test Loss: 2.330068, Test Acc: 0.702428
# epoch: 57, Train Loss: 0.003682, Train Acc: 0.999820, Test Loss: 2.343660, Test Acc: 0.702826
# epoch: 58, Train Loss: 0.003570, Train Acc: 0.999820, Test Loss: 2.353030, Test Acc: 0.702528
# epoch: 59, Train Loss: 0.003460, Train Acc: 0.999820, Test Loss: 2.366420, Test Acc: 0.703125
# lr is set to 0.0025418658283290017
# epoch: 60, Train Loss: 0.003347, Train Acc: 0.999820, Test Loss: 2.378109, Test Acc: 0.702627
# epoch: 61, Train Loss: 0.003310, Train Acc: 0.999820, Test Loss: 2.390001, Test Acc: 0.701632
# epoch: 62, Train Loss: 0.003030, Train Acc: 0.999840, Test Loss: 2.401973, Test Acc: 0.702826
# epoch: 63, Train Loss: 0.002918, Train Acc: 0.999860, Test Loss: 2.407810, Test Acc: 0.702030
# epoch: 64, Train Loss: 0.002747, Train Acc: 0.999880, Test Loss: 2.417893, Test Acc: 0.702826
# lr is set to 0.0022876792454961017
# epoch: 65, Train Loss: 0.002658, Train Acc: 0.999880, Test Loss: 2.426493, Test Acc: 0.702229
# epoch: 66, Train Loss: 0.002598, Train Acc: 0.999880, Test Loss: 2.434764, Test Acc: 0.701831
# epoch: 67, Train Loss: 0.002541, Train Acc: 0.999880, Test Loss: 2.445216, Test Acc: 0.702030
# epoch: 68, Train Loss: 0.002485, Train Acc: 0.999880, Test Loss: 2.451914, Test Acc: 0.702428
# epoch: 69, Train Loss: 0.002451, Train Acc: 0.999880, Test Loss: 2.459521, Test Acc: 0.702528
# lr is set to 0.0020589113209464917
# epoch: 70, Train Loss: 0.002288, Train Acc: 0.999900, Test Loss: 2.468334, Test Acc: 0.702329
# epoch: 71, Train Loss: 0.002225, Train Acc: 0.999900, Test Loss: 2.476167, Test Acc: 0.701732
# epoch: 72, Train Loss: 0.002181, Train Acc: 0.999900, Test Loss: 2.481046, Test Acc: 0.702229
# epoch: 73, Train Loss: 0.002136, Train Acc: 0.999900, Test Loss: 2.488612, Test Acc: 0.702130
# epoch: 74, Train Loss: 0.002098, Train Acc: 0.999900, Test Loss: 2.496933, Test Acc: 0.702130
# lr is set to 0.0018530201888518425
# epoch: 75, Train Loss: 0.002058, Train Acc: 0.999900, Test Loss: 2.502547, Test Acc: 0.702329
# epoch: 76, Train Loss: 0.002024, Train Acc: 0.999900, Test Loss: 2.510359, Test Acc: 0.701732
# epoch: 77, Train Loss: 0.001993, Train Acc: 0.999900, Test Loss: 2.515082, Test Acc: 0.702030
# epoch: 78, Train Loss: 0.001965, Train Acc: 0.999900, Test Loss: 2.522233, Test Acc: 0.701632
# epoch: 79, Train Loss: 0.001936, Train Acc: 0.999900, Test Loss: 2.528255, Test Acc: 0.702926
# lr is set to 0.0016677181699666583
# epoch: 80, Train Loss: 0.001911, Train Acc: 0.999900, Test Loss: 2.532900, Test Acc: 0.701931
# epoch: 81, Train Loss: 0.001813, Train Acc: 0.999920, Test Loss: 2.538057, Test Acc: 0.702329
# epoch: 82, Train Loss: 0.001775, Train Acc: 0.999920, Test Loss: 2.543557, Test Acc: 0.702329
# epoch: 83, Train Loss: 0.001750, Train Acc: 0.999920, Test Loss: 2.548950, Test Acc: 0.702229
# epoch: 84, Train Loss: 0.001726, Train Acc: 0.999920, Test Loss: 2.553093, Test Acc: 0.702030
# lr is set to 0.0015009463529699924
# epoch: 85, Train Loss: 0.001701, Train Acc: 0.999920, Test Loss: 2.557605, Test Acc: 0.702329
# epoch: 86, Train Loss: 0.001679, Train Acc: 0.999920, Test Loss: 2.563097, Test Acc: 0.701931
# epoch: 87, Train Loss: 0.001662, Train Acc: 0.999920, Test Loss: 2.566647, Test Acc: 0.702727
# epoch: 88, Train Loss: 0.001643, Train Acc: 0.999920, Test Loss: 2.571789, Test Acc: 0.701831
# epoch: 89, Train Loss: 0.001625, Train Acc: 0.999920, Test Loss: 2.576138, Test Acc: 0.701931
# lr is set to 0.0013508517176729932
# epoch: 90, Train Loss: 0.001604, Train Acc: 0.999920, Test Loss: 2.579996, Test Acc: 0.702727
# epoch: 91, Train Loss: 0.001589, Train Acc: 0.999920, Test Loss: 2.584105, Test Acc: 0.702528
# epoch: 92, Train Loss: 0.001574, Train Acc: 0.999920, Test Loss: 2.586746, Test Acc: 0.702030
# epoch: 93, Train Loss: 0.001558, Train Acc: 0.999920, Test Loss: 2.591734, Test Acc: 0.702030
# epoch: 94, Train Loss: 0.001545, Train Acc: 0.999920, Test Loss: 2.594797, Test Acc: 0.702428
# lr is set to 0.001215766545905694
# epoch: 95, Train Loss: 0.001529, Train Acc: 0.999920, Test Loss: 2.598162, Test Acc: 0.702428
# epoch: 96, Train Loss: 0.001521, Train Acc: 0.999920, Test Loss: 2.600797, Test Acc: 0.701831
# epoch: 97, Train Loss: 0.001477, Train Acc: 0.999920, Test Loss: 2.604397, Test Acc: 0.702130
# epoch: 98, Train Loss: 0.001446, Train Acc: 0.999920, Test Loss: 2.607954, Test Acc: 0.702130
# epoch: 99, Train Loss: 0.001422, Train Acc: 0.999920, Test Loss: 2.612740, Test Acc: 0.701135
# time used:  0:34:30.499380

# %%
# 测试模型在一个或数个batch的分类情况，并输出图像及对应预测名称，打印正确率
print('start testing')
#加载模型
model_test = torch.load('./model/model_addol.ckpt')
#设置模型为评估模式
model_test.eval()
#设置测试集
mytest = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transforms.ToTensor())
mytest_loader = torch.utils.data.DataLoader(mytest, batch_size=test_batch_size, shuffle=True)
#归一化
test_transform = transforms.Compose([
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    # transforms.ToPILImage()
])
eval_loss = 0
eval_acc = 0
fig = plt.figure()
#batch 循环
for i,(img,label) in enumerate(mytest_loader):
    img,label = img.to(device),label.to(device)
    test_img = img
    img = test_transform(img)
    out = model_test(img)
    loss = criterion(out,label)
    #记录误差
    eval_loss += loss.data.item()*label.size(0)
    #计算准确率
    _,pred = torch.max(out,1)
    num_correct = (pred == label).sum().item()
    eval_acc += num_correct

    #绘制图片（归一化后）
    if i == 0:
        for j in range(12):
            plt.subplot(3,4,j+1)
            plt.tight_layout()
            plt.imshow(test_img[j].permute(1,2,0), interpolation='none')
            plt.title('Prediction: {}'.format(classes[pred[j].item()]))
            plt.xticks([])
            plt.yticks([])
plt.show()
print('Test Loss: {:.6f}, Test Acc: {:.6f}'.format(eval_loss/len(mytest), eval_acc/len(mytest)))
# Out:
# start testing
# C:\Users\Darwin_\AppData\Local\Temp\ipykernel_444\611159001.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_test = torch.load('./model/model_addol.ckpt')
# Test Loss: 2.609220, Test Acc: 0.701500
