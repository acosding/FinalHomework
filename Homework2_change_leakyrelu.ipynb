# %%
# 导入相应的库
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np

import datetime

# %%
# 定义超参数
# 训练批次大小
train_batch_size = 64
# 测试批次大小
test_batch_size = 64
# 学习率
learning_rate = 0.01
# 迭代次数
num_epoches = 100

#动量
momentum = 0

#丢弃率
dropout_rate = 0.5
#判断是否有GPU，如果有则使用GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') 

#标签顺序
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# 定义预处理函数
transform = transforms.Compose([
    #将图像数据转换为张量
    transforms.ToTensor(), 
    #将图像数据归一化到[-1,1]
    #transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    #随机水平翻转
    # transforms.RandomHorizontalFlip(),
    # #随机遮挡
    # transforms.RandomErasing(scale=(0.04,0.2), ratio=(0.5,2)),
    # #随机裁剪
    # transforms.RandomCrop(32, padding=4)
])  

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
])
#下载数据，并对数据进行预处理
mnist_train= torchvision.datasets.CIFAR10(root='./data', train=True, transform=transform,download=True) 
mnist_test= torchvision.datasets.CIFAR10(root='./data', train=False, transform=transform_test,download=True)
mnist_show= torchvision.datasets.CIFAR10(root='./data', train=False, transform=transforms.ToTensor(),download=False)
#得到一个生成器
train_loader = DataLoader(mnist_train, batch_size=train_batch_size)
test_loader = DataLoader(mnist_test, batch_size=test_batch_size)
show_loader = DataLoader(mnist_show, batch_size=test_batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# 可视化源数据
# 打印测试集数据标签
examples = enumerate(show_loader) #用于将一个可遍历的数据对象(如列表、元组或字符串)组合为一个索引序列，同时列出数据和数据下标

batch_idx, (imgs, labels) = next(examples) #读取数据,batch_idx从0开始
#绘制部分数据图像
fig = plt.figure() #创建一个图像
for i in range(12):
    plt.subplot(3,4,i+1) #3行4列，第i+1个子图
    plt.tight_layout() #自动调整子图参数,使之填充整个图像区域
    plt.imshow(imgs[i].permute(1,2,0), interpolation='none') #绘制图像
    plt.title("Ground Truth: {}".format(classes[labels[i].item()])) #设置标题
    plt.xticks([]) #设置x轴刻度为空
    plt.yticks([]) #设置y轴刻度为空
plt.show() #显示图像
print(labels) #读取标签数据
print(labels.shape) #torch.Size([32])，因为batch_size为32
# Out:
# tensor([3, 8, 8, 0, 6, 6, 1, 6, 3, 1, 0, 9, 5, 7, 9, 8, 5, 7, 8, 6, 7, 0, 4, 9,
#         5, 2, 4, 0, 9, 6, 6, 5, 4, 5, 9, 2, 4, 1, 9, 5, 4, 6, 5, 6, 0, 9, 3, 9,
#         7, 6, 9, 8, 0, 3, 8, 8, 7, 7, 4, 6, 7, 3, 6, 3])
# torch.Size([64])

# %%
# 构建模型
class Net(nn.Module):
    # """
    # 使用sequential构建网络，Sequential()函数的功能是将网络的层组合到一起
    # """
    def __init__(self):
        super(Net, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 32, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 32, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Flatten(),
            nn.Linear(64*4*4, 64),
            # 激活函数
            nn.LeakyReLU(0.01,True),
            #新增的隐藏层
            # nn.Linear(256, 64),
            # 激活函数
            # nn.ReLU(True),
            nn.Linear(64, 10),
            nn.LeakyReLU(0.01,True),
        )
    def forward(self, x):
        x = self.model(x)
        return x
    
#创建模型实例
model = Net().to(device)
# 损失函数
criterion = nn.CrossEntropyLoss().to(device)
# 优化器
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum)
# 其他几种优化算法：
# opt_SGD = torch.optim.SGD(net_SGD.parameters(), lr=LR)
# opt_Momentum = torch.optim.SGD(net_Momentum.parameters(), lr=LR, momentum=0.9)
# opt_RMSProp = torch.optim.RMSprop(net_RMSProp.parameters(), lr=LR, alpha=0.9)
# opt_Adam = torch.optim.Adam(net_Adam.parameters(), lr=LR, betas=(0.9, 0.99))

# %%
# 训练模型并绘制Loss函数曲线
print('start training')
iterations = 0
#记录数据
losses = []
acces = []
eval_losses = []
eval_acces = []

#开始计时
start = datetime.datetime.now()

for epoch in range(num_epoches):
    train_loss = 0
    train_acc = 0
    model.train()
    #动态修改学习率
    if epoch%5==0:
        optimizer.param_groups[0]['lr']*=0.9
        print('lr is set to {}'.format(optimizer.param_groups[0]['lr']))
    for img,label in train_loader:
        img,label = img.to(device),label.to(device)
        #前向传播
        out = model(img)
        #计算损失
        loss = criterion(out,label)
        #反向传播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #记录误差
        train_loss += loss.item()
        #计算准确率
        _,pred = torch.max(out,1)
        num_correct = (pred == label).sum().item()
        acc = num_correct/img.shape[0]
        train_acc += acc
    losses.append(train_loss/len(train_loader))
    acces.append(train_acc/len(train_loader))
    #在测试集上测试
    eval_loss = 0
    eval_acc = 0

    model.eval()
    for img,label in test_loader:
        img,label = img.to(device),label.to(device)
        out = model(img)
        loss = criterion(out,label)
        #记录误差
        eval_loss += loss.item()
        #计算准确率
        _,pred = torch.max(out,1)
        num_correct = (pred == label).sum().item()
        acc = num_correct/img.shape[0]
        eval_acc += acc
    eval_losses.append(eval_loss/len(test_loader))
    eval_acces.append(eval_acc/len(test_loader))
    print('epoch: {}, Train Loss: {:.6f}, Train Acc: {:.6f}, Test Loss: {:.6f}, Test Acc: {:.6f}'
          .format(epoch, train_loss/len(train_loader), train_acc/len(train_loader), 
                  eval_loss/len(test_loader), eval_acc/len(test_loader)))
#结束计时
end = datetime.datetime.now()
# 绘制损失函数曲线
plt.title('train loss')
plt.plot(np.arange(len(losses)), losses, "blue", label="Training Loss")
plt.plot(np.arange(len(eval_losses)), eval_losses, "red", label="Test Loss")
plt.xlim([0,epoch])
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend(['Train Loss', 'Test Loss'], loc='upper right')
plt.savefig('./loss_LR.png')
# 计算训练时间
print('time used: ', end-start)
torch.save(model,'./model/model_LR.ckpt')
# Out:
# start training
# lr is set to 0.009000000000000001
# epoch: 0, Train Loss: 1.976333, Train Acc: 0.290361, Test Loss: 1.826313, Test Acc: 0.326234
# epoch: 1, Train Loss: 1.552834, Train Acc: 0.444453, Test Loss: 1.638472, Test Acc: 0.405255
# epoch: 2, Train Loss: 1.387192, Train Acc: 0.507273, Test Loss: 1.393342, Test Acc: 0.495422
# epoch: 3, Train Loss: 1.266247, Train Acc: 0.554208, Test Loss: 1.285119, Test Acc: 0.539212
# epoch: 4, Train Loss: 1.168558, Train Acc: 0.590213, Test Loss: 1.217960, Test Acc: 0.565386
# lr is set to 0.008100000000000001
# epoch: 5, Train Loss: 1.084725, Train Acc: 0.623521, Test Loss: 1.129835, Test Acc: 0.599124
# epoch: 6, Train Loss: 1.023128, Train Acc: 0.645061, Test Loss: 1.094883, Test Acc: 0.613157
# epoch: 7, Train Loss: 0.968441, Train Acc: 0.666660, Test Loss: 1.070043, Test Acc: 0.622512
# epoch: 8, Train Loss: 0.919609, Train Acc: 0.682545, Test Loss: 1.089973, Test Acc: 0.622313
# epoch: 9, Train Loss: 0.876190, Train Acc: 0.698729, Test Loss: 1.107320, Test Acc: 0.618929
# lr is set to 0.007290000000000001
# epoch: 10, Train Loss: 0.828855, Train Acc: 0.713515, Test Loss: 1.089895, Test Acc: 0.625597
# epoch: 11, Train Loss: 0.795048, Train Acc: 0.725603, Test Loss: 1.064125, Test Acc: 0.634952
# epoch: 12, Train Loss: 0.762617, Train Acc: 0.736813, Test Loss: 1.077159, Test Acc: 0.635052
# epoch: 13, Train Loss: 0.731512, Train Acc: 0.746983, Test Loss: 1.078331, Test Acc: 0.638734
# epoch: 14, Train Loss: 0.701324, Train Acc: 0.757832, Test Loss: 1.062009, Test Acc: 0.644904
# lr is set to 0.006561000000000002
# epoch: 15, Train Loss: 0.663919, Train Acc: 0.770640, Test Loss: 1.004929, Test Acc: 0.662719
# epoch: 16, Train Loss: 0.636458, Train Acc: 0.780651, Test Loss: 0.999578, Test Acc: 0.667795
# epoch: 17, Train Loss: 0.610756, Train Acc: 0.791021, Test Loss: 0.999601, Test Acc: 0.670780
# epoch: 18, Train Loss: 0.584742, Train Acc: 0.800412, Test Loss: 1.001246, Test Acc: 0.672771
# epoch: 19, Train Loss: 0.559511, Train Acc: 0.809143, Test Loss: 1.011860, Test Acc: 0.672970
# lr is set to 0.005904900000000002
# epoch: 20, Train Loss: 0.526064, Train Acc: 0.821831, Test Loss: 1.009507, Test Acc: 0.678344
# epoch: 21, Train Loss: 0.502636, Train Acc: 0.830543, Test Loss: 1.024331, Test Acc: 0.679140
# epoch: 22, Train Loss: 0.480100, Train Acc: 0.839954, Test Loss: 1.038058, Test Acc: 0.679041
# epoch: 23, Train Loss: 0.457542, Train Acc: 0.848306, Test Loss: 1.049683, Test Acc: 0.682922
# epoch: 24, Train Loss: 0.435362, Train Acc: 0.857457, Test Loss: 1.059644, Test Acc: 0.684813
# lr is set to 0.005314410000000002
# epoch: 25, Train Loss: 0.405429, Train Acc: 0.868626, Test Loss: 1.067859, Test Acc: 0.689789
# epoch: 26, Train Loss: 0.384685, Train Acc: 0.876638, Test Loss: 1.094116, Test Acc: 0.690386
# epoch: 27, Train Loss: 0.364642, Train Acc: 0.884351, Test Loss: 1.119534, Test Acc: 0.691580
# epoch: 28, Train Loss: 0.344945, Train Acc: 0.891884, Test Loss: 1.155624, Test Acc: 0.690585
# epoch: 29, Train Loss: 0.325349, Train Acc: 0.900675, Test Loss: 1.184845, Test Acc: 0.689590
# lr is set to 0.004782969000000002
# epoch: 30, Train Loss: 0.299176, Train Acc: 0.909687, Test Loss: 1.210937, Test Acc: 0.689291
# epoch: 31, Train Loss: 0.280621, Train Acc: 0.917359, Test Loss: 1.251827, Test Acc: 0.687600
# epoch: 32, Train Loss: 0.262944, Train Acc: 0.923773, Test Loss: 1.289322, Test Acc: 0.686206
# epoch: 33, Train Loss: 0.245675, Train Acc: 0.930067, Test Loss: 1.330141, Test Acc: 0.687301
# epoch: 34, Train Loss: 0.228683, Train Acc: 0.936721, Test Loss: 1.375999, Test Acc: 0.684813
# lr is set to 0.004304672100000002
# epoch: 35, Train Loss: 0.207252, Train Acc: 0.945412, Test Loss: 1.410021, Test Acc: 0.683619
# epoch: 36, Train Loss: 0.190532, Train Acc: 0.951846, Test Loss: 1.451933, Test Acc: 0.683021
# epoch: 37, Train Loss: 0.175614, Train Acc: 0.957541, Test Loss: 1.499331, Test Acc: 0.681529
# epoch: 38, Train Loss: 0.161529, Train Acc: 0.962996, Test Loss: 1.549120, Test Acc: 0.681728
# epoch: 39, Train Loss: 0.147530, Train Acc: 0.967811, Test Loss: 1.601066, Test Acc: 0.682225
# lr is set to 0.003874204890000002
# epoch: 40, Train Loss: 0.131582, Train Acc: 0.972926, Test Loss: 1.643899, Test Acc: 0.682325
# epoch: 41, Train Loss: 0.119085, Train Acc: 0.977242, Test Loss: 1.687143, Test Acc: 0.682026
# epoch: 42, Train Loss: 0.107649, Train Acc: 0.980738, Test Loss: 1.731948, Test Acc: 0.681230
# epoch: 43, Train Loss: 0.097302, Train Acc: 0.983836, Test Loss: 1.785466, Test Acc: 0.681628
# epoch: 44, Train Loss: 0.087907, Train Acc: 0.986593, Test Loss: 1.830894, Test Acc: 0.681429
# lr is set to 0.003486784401000002
# epoch: 45, Train Loss: 0.078589, Train Acc: 0.989110, Test Loss: 1.872343, Test Acc: 0.681529
# epoch: 46, Train Loss: 0.070623, Train Acc: 0.991069, Test Loss: 1.918992, Test Acc: 0.682723
# epoch: 47, Train Loss: 0.063911, Train Acc: 0.992827, Test Loss: 1.959970, Test Acc: 0.681628
# epoch: 48, Train Loss: 0.057794, Train Acc: 0.993766, Test Loss: 2.002390, Test Acc: 0.682225
# epoch: 49, Train Loss: 0.052340, Train Acc: 0.994665, Test Loss: 2.042532, Test Acc: 0.682325
# lr is set to 0.003138105960900002
# epoch: 50, Train Loss: 0.047631, Train Acc: 0.995604, Test Loss: 2.075997, Test Acc: 0.682822
# epoch: 51, Train Loss: 0.043397, Train Acc: 0.996044, Test Loss: 2.110137, Test Acc: 0.682723
# epoch: 52, Train Loss: 0.039691, Train Acc: 0.996543, Test Loss: 2.144712, Test Acc: 0.682225
# epoch: 53, Train Loss: 0.036382, Train Acc: 0.996983, Test Loss: 2.178523, Test Acc: 0.682225
# epoch: 54, Train Loss: 0.033427, Train Acc: 0.997442, Test Loss: 2.209649, Test Acc: 0.682026
# lr is set to 0.0028242953648100018
# epoch: 55, Train Loss: 0.031169, Train Acc: 0.997682, Test Loss: 2.238427, Test Acc: 0.683320
# epoch: 56, Train Loss: 0.028925, Train Acc: 0.997902, Test Loss: 2.264824, Test Acc: 0.683221
# epoch: 57, Train Loss: 0.026920, Train Acc: 0.998082, Test Loss: 2.290180, Test Acc: 0.683619
# epoch: 58, Train Loss: 0.025151, Train Acc: 0.998122, Test Loss: 2.316289, Test Acc: 0.683519
# epoch: 59, Train Loss: 0.023556, Train Acc: 0.998202, Test Loss: 2.341735, Test Acc: 0.684912
# lr is set to 0.0025418658283290017
# epoch: 60, Train Loss: 0.022367, Train Acc: 0.998282, Test Loss: 2.361409, Test Acc: 0.685211
# epoch: 61, Train Loss: 0.021076, Train Acc: 0.998302, Test Loss: 2.382411, Test Acc: 0.684713
# epoch: 62, Train Loss: 0.019948, Train Acc: 0.998362, Test Loss: 2.402808, Test Acc: 0.684912
# epoch: 63, Train Loss: 0.018904, Train Acc: 0.998382, Test Loss: 2.423880, Test Acc: 0.685211
# epoch: 64, Train Loss: 0.017962, Train Acc: 0.998402, Test Loss: 2.443575, Test Acc: 0.684813
# lr is set to 0.0022876792454961017
# epoch: 65, Train Loss: 0.017278, Train Acc: 0.998441, Test Loss: 2.459742, Test Acc: 0.684514
# epoch: 66, Train Loss: 0.016514, Train Acc: 0.998441, Test Loss: 2.477574, Test Acc: 0.685111
# epoch: 67, Train Loss: 0.015801, Train Acc: 0.998501, Test Loss: 2.493935, Test Acc: 0.686206
# epoch: 68, Train Loss: 0.015149, Train Acc: 0.998541, Test Loss: 2.511957, Test Acc: 0.685808
# epoch: 69, Train Loss: 0.014522, Train Acc: 0.998561, Test Loss: 2.528344, Test Acc: 0.685111
# lr is set to 0.0020589113209464917
# epoch: 70, Train Loss: 0.014116, Train Acc: 0.998561, Test Loss: 2.541964, Test Acc: 0.685410
# epoch: 71, Train Loss: 0.013613, Train Acc: 0.998581, Test Loss: 2.554860, Test Acc: 0.685410
# epoch: 72, Train Loss: 0.013103, Train Acc: 0.998621, Test Loss: 2.570493, Test Acc: 0.685510
# epoch: 73, Train Loss: 0.012676, Train Acc: 0.998641, Test Loss: 2.583923, Test Acc: 0.685808
# epoch: 74, Train Loss: 0.012267, Train Acc: 0.998641, Test Loss: 2.598342, Test Acc: 0.685510
# lr is set to 0.0018530201888518425
# epoch: 75, Train Loss: 0.012008, Train Acc: 0.998641, Test Loss: 2.609741, Test Acc: 0.684912
# epoch: 76, Train Loss: 0.011672, Train Acc: 0.998661, Test Loss: 2.620920, Test Acc: 0.684912
# epoch: 77, Train Loss: 0.011355, Train Acc: 0.998661, Test Loss: 2.632738, Test Acc: 0.684912
# epoch: 78, Train Loss: 0.011050, Train Acc: 0.998661, Test Loss: 2.644117, Test Acc: 0.684813
# epoch: 79, Train Loss: 0.010779, Train Acc: 0.998661, Test Loss: 2.656479, Test Acc: 0.685012
# lr is set to 0.0016677181699666583
# epoch: 80, Train Loss: 0.010605, Train Acc: 0.998661, Test Loss: 2.665356, Test Acc: 0.684713
# epoch: 81, Train Loss: 0.010363, Train Acc: 0.998661, Test Loss: 2.676480, Test Acc: 0.684614
# epoch: 82, Train Loss: 0.010136, Train Acc: 0.998661, Test Loss: 2.686022, Test Acc: 0.685410
# epoch: 83, Train Loss: 0.009915, Train Acc: 0.998661, Test Loss: 2.695388, Test Acc: 0.684912
# epoch: 84, Train Loss: 0.009728, Train Acc: 0.998661, Test Loss: 2.707063, Test Acc: 0.685311
# lr is set to 0.0015009463529699924
# epoch: 85, Train Loss: 0.009624, Train Acc: 0.998681, Test Loss: 2.713079, Test Acc: 0.685311
# epoch: 86, Train Loss: 0.009429, Train Acc: 0.998681, Test Loss: 2.723474, Test Acc: 0.684912
# epoch: 87, Train Loss: 0.009252, Train Acc: 0.998681, Test Loss: 2.731219, Test Acc: 0.684813
# epoch: 88, Train Loss: 0.009087, Train Acc: 0.998681, Test Loss: 2.738975, Test Acc: 0.685410
# epoch: 89, Train Loss: 0.008929, Train Acc: 0.998681, Test Loss: 2.748914, Test Acc: 0.684415
# lr is set to 0.0013508517176729932
# epoch: 90, Train Loss: 0.008841, Train Acc: 0.998681, Test Loss: 2.754006, Test Acc: 0.685510
# epoch: 91, Train Loss: 0.008696, Train Acc: 0.998681, Test Loss: 2.764248, Test Acc: 0.684912
# epoch: 92, Train Loss: 0.008569, Train Acc: 0.998701, Test Loss: 2.767980, Test Acc: 0.685510
# epoch: 93, Train Loss: 0.008447, Train Acc: 0.998701, Test Loss: 2.776367, Test Acc: 0.685709
# epoch: 94, Train Loss: 0.008329, Train Acc: 0.998701, Test Loss: 2.783488, Test Acc: 0.684813
# lr is set to 0.001215766545905694
# epoch: 95, Train Loss: 0.008274, Train Acc: 0.998701, Test Loss: 2.788391, Test Acc: 0.684216
# epoch: 96, Train Loss: 0.008155, Train Acc: 0.998701, Test Loss: 2.797110, Test Acc: 0.684415
# epoch: 97, Train Loss: 0.008067, Train Acc: 0.998701, Test Loss: 2.800772, Test Acc: 0.684813
# epoch: 98, Train Loss: 0.007963, Train Acc: 0.998701, Test Loss: 2.810102, Test Acc: 0.683917
# epoch: 99, Train Loss: 0.007882, Train Acc: 0.998701, Test Loss: 2.813094, Test Acc: 0.684813
# time used:  0:36:36.402356

# %%
# 测试模型在一个或数个batch的分类情况，并输出图像及对应预测名称，打印正确率
print('start testing')
#加载模型
model_test = torch.load('./model/model_LR.ckpt')
#设置模型为评估模式
model_test.eval()
#设置测试集
mytest = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transforms.ToTensor(),download=True)
mytest_loader = torch.utils.data.DataLoader(mytest, batch_size=test_batch_size, shuffle=True)
#归一化
test_transform = transforms.Compose([
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    # transforms.ToPILImage()
])
eval_loss = 0
eval_acc = 0
fig = plt.figure()
#batch 循环
for i,(img,label) in enumerate(mytest_loader):
    img,label = img.to(device),label.to(device)
    test_img = img
    img = test_transform(img)
    out = model_test(img)
    loss = criterion(out,label)
    #记录误差
    eval_loss += loss.data.item()*label.size(0)
    #计算准确率
    _,pred = torch.max(out,1)
    num_correct = (pred == label).sum().item()
    eval_acc += num_correct

    #绘制图片（归一化后）
    if i == 0:
        for j in range(6):
            plt.subplot(2,3,j+1)
            plt.tight_layout()
            plt.imshow(test_img[j].permute(1,2,0), interpolation='none')
            plt.title('Prediction: {}'.format(classes[pred[j].item()]))
            plt.xticks([])
            plt.yticks([])
plt.show()
print('Test Loss: {:.6f}, Test Acc: {:.6f}'.format(eval_loss/len(mytest), eval_acc/len(mytest)))
# Out:
# start testing
# C:\Users\Darwin_\AppData\Local\Temp\ipykernel_2124\1835135859.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_test = torch.load('./model/model_LR.ckpt')
# Files already downloaded and verified
# Test Loss: 2.798215, Test Acc: 0.685400
