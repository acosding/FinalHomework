# %%
# 导入相应的库
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np

import datetime

# %%
# 定义超参数
# 训练批次大小
train_batch_size = 64
# 测试批次大小
test_batch_size = 64
# 学习率
learning_rate = 0.001
# 迭代次数
num_epoches = 100

#动量
momentum = 0.5

#丢弃率
dropout_rate = 0.5
#判断是否有GPU，如果有则使用GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') 

#标签顺序
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# 定义预处理函数
transform = transforms.Compose([
    #将图像数据转换为张量
    transforms.ToTensor(), 
    #将图像数据归一化到[-1,1]
    #transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    # #随机水平翻转
    # transforms.RandomHorizontalFlip(),
    # #随机遮挡
    # transforms.RandomErasing(scale=(0.04,0.2), ratio=(0.5,2)),
    # #随机裁剪
    # transforms.RandomCrop(32, padding=4)
])  

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
])
#下载数据，并对数据进行预处理
mnist_train= torchvision.datasets.CIFAR10(root='./data', train=True, transform=transform,download=True) 
mnist_test= torchvision.datasets.CIFAR10(root='./data', train=False, transform=transform_test,download=True)
mnist_show= torchvision.datasets.CIFAR10(root='./data', train=False, transform=transforms.ToTensor(),download=False)
#得到一个生成器
train_loader = DataLoader(mnist_train, batch_size=train_batch_size)
test_loader = DataLoader(mnist_test, batch_size=test_batch_size)
show_loader = DataLoader(mnist_show, batch_size=test_batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# 可视化源数据
# 打印测试集数据标签
examples = enumerate(show_loader) #用于将一个可遍历的数据对象(如列表、元组或字符串)组合为一个索引序列，同时列出数据和数据下标

batch_idx, (imgs, labels) = next(examples) #读取数据,batch_idx从0开始
#绘制部分数据图像
fig = plt.figure() #创建一个图像
for i in range(12):
    plt.subplot(3,4,i+1) #3行4列，第i+1个子图
    plt.tight_layout() #自动调整子图参数,使之填充整个图像区域
    plt.imshow(imgs[i].permute(1,2,0), interpolation='none') #绘制图像
    plt.title("Ground Truth: {}".format(classes[labels[i].item()])) #设置标题
    plt.xticks([]) #设置x轴刻度为空
    plt.yticks([]) #设置y轴刻度为空
plt.show() #显示图像
print(labels) #读取标签数据
print(labels.shape) #torch.Size([32])，因为batch_size为32
# Out:
# tensor([3, 8, 8, 0, 6, 6, 1, 6, 3, 1, 0, 9, 5, 7, 9, 8, 5, 7, 8, 6, 7, 0, 4, 9,
#         5, 2, 4, 0, 9, 6, 6, 5, 4, 5, 9, 2, 4, 1, 9, 5, 4, 6, 5, 6, 0, 9, 3, 9,
#         7, 6, 9, 8, 0, 3, 8, 8, 7, 7, 4, 6, 7, 3, 6, 3])
# torch.Size([64])

# %%
# 构建模型
class Net(nn.Module):
    # """
    # 使用sequential构建网络，Sequential()函数的功能是将网络的层组合到一起
    # """
    def __init__(self):
        super(Net, self).__init__()
        self.model = nn.Sequential(
            #lenet-5
            nn.Conv2d(3, 32, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 32, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Flatten(),
            nn.Linear(64*4*4, 64),
            # 激活函数
            nn.ReLU(True),
            #新增的隐藏层
            # nn.Linear(256, 64),
            # 激活函数
            # nn.ReLU(True),
            nn.Linear(64, 10),
            nn.ReLU(True),
        )
    def forward(self, x):
        x = self.model(x)
        return x
    
#创建模型实例
model = Net().to(device)
# 损失函数
criterion = nn.CrossEntropyLoss().to(device)
# 优化器
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.99))
# 其他几种优化算法：
# opt_SGD = torch.optim.SGD(net_SGD.parameters(), lr=LR)
# opt_Momentum = torch.optim.SGD(net_Momentum.parameters(), lr=LR, momentum=0.9)
# opt_RMSProp = torch.optim.RMSprop(net_RMSProp.parameters(), lr=LR, alpha=0.9)
# opt_Adam = torch.optim.Adam(net_Adam.parameters(), lr=LR, betas=(0.9, 0.99))

# %%
# 训练模型并绘制Loss函数曲线
print('start training')
iterations = 0
#记录数据
losses = []
acces = []
eval_losses = []
eval_acces = []

#开始计时
start = datetime.datetime.now()

for epoch in range(num_epoches):
    train_loss = 0
    train_acc = 0
    model.train()
    #动态修改学习率
    if epoch%5==0:
        optimizer.param_groups[0]['lr']*=0.9
        print('lr is set to {}'.format(optimizer.param_groups[0]['lr']))
    for img,label in train_loader:
        img,label = img.to(device),label.to(device)
        #前向传播
        out = model(img)
        #计算损失
        loss = criterion(out,label)
        #反向传播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #记录误差
        train_loss += loss.item()
        #计算准确率
        _,pred = torch.max(out,1)
        num_correct = (pred == label).sum().item()
        acc = num_correct/img.shape[0]
        train_acc += acc
    losses.append(train_loss/len(train_loader))
    acces.append(train_acc/len(train_loader))
    #在测试集上测试
    eval_loss = 0
    eval_acc = 0

    model.eval()
    for img,label in test_loader:
        img,label = img.to(device),label.to(device)
        out = model(img)
        loss = criterion(out,label)
        #记录误差
        eval_loss += loss.item()
        #计算准确率
        _,pred = torch.max(out,1)
        num_correct = (pred == label).sum().item()
        acc = num_correct/img.shape[0]
        eval_acc += acc
    eval_losses.append(eval_loss/len(test_loader))
    eval_acces.append(eval_acc/len(test_loader))
    print('epoch: {}, Train Loss: {:.6f}, Train Acc: {:.6f}, Test Loss: {:.6f}, Test Acc: {:.6f}'
          .format(epoch, train_loss/len(train_loader), train_acc/len(train_loader), 
                  eval_loss/len(test_loader), eval_acc/len(test_loader)))
#结束计时
end = datetime.datetime.now()
# 绘制损失函数曲线
plt.title('train loss')
plt.plot(np.arange(len(losses)), losses, "blue", label="Training Loss")
plt.plot(np.arange(len(eval_losses)), eval_losses, "red", label="Test Loss")
plt.xlim([0,epoch])
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend(['Train Loss', 'Test Loss'], loc='upper right')
plt.savefig('./loss_momentum.png')
# 计算训练时间
print('time used: ', end-start)
torch.save(model,'./model/model_momentum.ckpt')
# Out:
# start training
# lr is set to 0.0009000000000000001
# epoch: 0, Train Loss: 1.494712, Train Acc: 0.482797, Test Loss: 1.108666, Test Acc: 0.612361
# epoch: 1, Train Loss: 1.005209, Train Acc: 0.650096, Test Loss: 0.971789, Test Acc: 0.664610
# epoch: 2, Train Loss: 0.844229, Train Acc: 0.706901, Test Loss: 0.973768, Test Acc: 0.675060
# epoch: 3, Train Loss: 0.731176, Train Acc: 0.746703, Test Loss: 0.980887, Test Acc: 0.683718
# epoch: 4, Train Loss: 0.648061, Train Acc: 0.775436, Test Loss: 1.024767, Test Acc: 0.684514
# lr is set to 0.0008100000000000001
# epoch: 5, Train Loss: 0.567967, Train Acc: 0.803309, Test Loss: 1.036885, Test Acc: 0.689988
# epoch: 6, Train Loss: 0.494726, Train Acc: 0.829544, Test Loss: 1.114310, Test Acc: 0.681330
# epoch: 7, Train Loss: 0.449189, Train Acc: 0.843310, Test Loss: 1.183282, Test Acc: 0.682325
# epoch: 8, Train Loss: 0.402399, Train Acc: 0.859974, Test Loss: 1.308179, Test Acc: 0.677150
# epoch: 9, Train Loss: 0.354442, Train Acc: 0.874580, Test Loss: 1.457814, Test Acc: 0.659634
# lr is set to 0.000729
# epoch: 10, Train Loss: 0.328033, Train Acc: 0.885870, Test Loss: 1.508952, Test Acc: 0.662420
# epoch: 11, Train Loss: 0.283019, Train Acc: 0.899936, Test Loss: 1.575739, Test Acc: 0.667994
# epoch: 12, Train Loss: 0.255340, Train Acc: 0.909487, Test Loss: 1.675154, Test Acc: 0.666003
# epoch: 13, Train Loss: 0.235481, Train Acc: 0.917839, Test Loss: 1.781898, Test Acc: 0.660430
# epoch: 14, Train Loss: 0.215694, Train Acc: 0.924652, Test Loss: 1.865828, Test Acc: 0.663615
# lr is set to 0.0006561000000000001
# epoch: 15, Train Loss: 0.191675, Train Acc: 0.933824, Test Loss: 1.934323, Test Acc: 0.661525
# epoch: 16, Train Loss: 0.170802, Train Acc: 0.939818, Test Loss: 2.072160, Test Acc: 0.658738
# epoch: 17, Train Loss: 0.165186, Train Acc: 0.942995, Test Loss: 2.128323, Test Acc: 0.670780
# epoch: 18, Train Loss: 0.166515, Train Acc: 0.944194, Test Loss: 2.249094, Test Acc: 0.657842
# epoch: 19, Train Loss: 0.149465, Train Acc: 0.949728, Test Loss: 2.325205, Test Acc: 0.659634
# lr is set to 0.00059049
# epoch: 20, Train Loss: 0.131339, Train Acc: 0.955083, Test Loss: 2.417146, Test Acc: 0.669486
# epoch: 21, Train Loss: 0.121449, Train Acc: 0.959399, Test Loss: 2.477025, Test Acc: 0.666700
# epoch: 22, Train Loss: 0.113475, Train Acc: 0.961897, Test Loss: 2.536845, Test Acc: 0.673368
# epoch: 23, Train Loss: 0.109062, Train Acc: 0.964194, Test Loss: 2.737969, Test Acc: 0.660928
# epoch: 24, Train Loss: 0.108505, Train Acc: 0.964454, Test Loss: 2.792077, Test Acc: 0.673766
# lr is set to 0.000531441
# epoch: 25, Train Loss: 0.095408, Train Acc: 0.968770, Test Loss: 2.722467, Test Acc: 0.666799
# epoch: 26, Train Loss: 0.085666, Train Acc: 0.971288, Test Loss: 2.767617, Test Acc: 0.678941
# epoch: 27, Train Loss: 0.080060, Train Acc: 0.973146, Test Loss: 2.785066, Test Acc: 0.677249
# epoch: 28, Train Loss: 0.088219, Train Acc: 0.971547, Test Loss: 2.802706, Test Acc: 0.675557
# epoch: 29, Train Loss: 0.082856, Train Acc: 0.972846, Test Loss: 2.881228, Test Acc: 0.672472
# lr is set to 0.0004782969
# epoch: 30, Train Loss: 0.068193, Train Acc: 0.977302, Test Loss: 2.862258, Test Acc: 0.673766
# epoch: 31, Train Loss: 0.067700, Train Acc: 0.977901, Test Loss: 3.061735, Test Acc: 0.671477
# epoch: 32, Train Loss: 0.066285, Train Acc: 0.978501, Test Loss: 3.011856, Test Acc: 0.674562
# epoch: 33, Train Loss: 0.065115, Train Acc: 0.978621, Test Loss: 3.079822, Test Acc: 0.675657
# epoch: 34, Train Loss: 0.063570, Train Acc: 0.979819, Test Loss: 3.234407, Test Acc: 0.670681
# lr is set to 0.00043046721
# epoch: 35, Train Loss: 0.055799, Train Acc: 0.981957, Test Loss: 3.210558, Test Acc: 0.679638
# epoch: 36, Train Loss: 0.049733, Train Acc: 0.984155, Test Loss: 3.220530, Test Acc: 0.666401
# epoch: 37, Train Loss: 0.053614, Train Acc: 0.982237, Test Loss: 3.398827, Test Acc: 0.675756
# epoch: 38, Train Loss: 0.051417, Train Acc: 0.983276, Test Loss: 3.335880, Test Acc: 0.674562
# epoch: 39, Train Loss: 0.050750, Train Acc: 0.984275, Test Loss: 3.355313, Test Acc: 0.678244
# lr is set to 0.000387420489
# epoch: 40, Train Loss: 0.041796, Train Acc: 0.986233, Test Loss: 3.389957, Test Acc: 0.674960
# epoch: 41, Train Loss: 0.038745, Train Acc: 0.987072, Test Loss: 3.465437, Test Acc: 0.679737
# epoch: 42, Train Loss: 0.040409, Train Acc: 0.986693, Test Loss: 3.638333, Test Acc: 0.678941
# epoch: 43, Train Loss: 0.042385, Train Acc: 0.986653, Test Loss: 3.499093, Test Acc: 0.676055
# epoch: 44, Train Loss: 0.037927, Train Acc: 0.987312, Test Loss: 3.615541, Test Acc: 0.678742
# lr is set to 0.0003486784401
# epoch: 45, Train Loss: 0.035034, Train Acc: 0.988591, Test Loss: 3.469142, Test Acc: 0.679439
# epoch: 46, Train Loss: 0.032990, Train Acc: 0.989090, Test Loss: 3.702563, Test Acc: 0.674960
# epoch: 47, Train Loss: 0.031600, Train Acc: 0.989850, Test Loss: 3.607074, Test Acc: 0.683320
# epoch: 48, Train Loss: 0.030809, Train Acc: 0.989770, Test Loss: 3.707842, Test Acc: 0.683718
# epoch: 49, Train Loss: 0.031271, Train Acc: 0.989950, Test Loss: 3.739999, Test Acc: 0.677249
# lr is set to 0.00031381059609000004
# epoch: 50, Train Loss: 0.027729, Train Acc: 0.991528, Test Loss: 3.897644, Test Acc: 0.675458
# epoch: 51, Train Loss: 0.025943, Train Acc: 0.991368, Test Loss: 3.873560, Test Acc: 0.678145
# epoch: 52, Train Loss: 0.026097, Train Acc: 0.991168, Test Loss: 3.918779, Test Acc: 0.680533
# epoch: 53, Train Loss: 0.024858, Train Acc: 0.991508, Test Loss: 4.004178, Test Acc: 0.681827
# epoch: 54, Train Loss: 0.026037, Train Acc: 0.991168, Test Loss: 4.090610, Test Acc: 0.686306
# lr is set to 0.00028242953648100003
# epoch: 55, Train Loss: 0.021627, Train Acc: 0.992767, Test Loss: 3.983495, Test Acc: 0.680732
# epoch: 56, Train Loss: 0.019550, Train Acc: 0.993027, Test Loss: 4.066343, Test Acc: 0.679240
# epoch: 57, Train Loss: 0.022100, Train Acc: 0.992487, Test Loss: 4.191808, Test Acc: 0.683121
# epoch: 58, Train Loss: 0.019821, Train Acc: 0.993306, Test Loss: 4.148534, Test Acc: 0.677249
# epoch: 59, Train Loss: 0.020845, Train Acc: 0.993286, Test Loss: 4.185407, Test Acc: 0.680135
# lr is set to 0.00025418658283290005
# epoch: 60, Train Loss: 0.019328, Train Acc: 0.993746, Test Loss: 4.095928, Test Acc: 0.679140
# epoch: 61, Train Loss: 0.017534, Train Acc: 0.994485, Test Loss: 4.160392, Test Acc: 0.675856
# epoch: 62, Train Loss: 0.017002, Train Acc: 0.994186, Test Loss: 4.324570, Test Acc: 0.683121
# epoch: 63, Train Loss: 0.017892, Train Acc: 0.994046, Test Loss: 4.189700, Test Acc: 0.681927
# epoch: 64, Train Loss: 0.017660, Train Acc: 0.993966, Test Loss: 4.262270, Test Acc: 0.680832
# lr is set to 0.00022876792454961005
# epoch: 65, Train Loss: 0.015105, Train Acc: 0.994965, Test Loss: 4.338022, Test Acc: 0.681628
# epoch: 66, Train Loss: 0.013898, Train Acc: 0.995305, Test Loss: 4.390625, Test Acc: 0.685709
# epoch: 67, Train Loss: 0.012434, Train Acc: 0.995404, Test Loss: 4.380636, Test Acc: 0.676154
# epoch: 68, Train Loss: 0.016912, Train Acc: 0.994585, Test Loss: 4.433180, Test Acc: 0.680135
# epoch: 69, Train Loss: 0.014259, Train Acc: 0.994905, Test Loss: 4.539063, Test Acc: 0.676254
# lr is set to 0.00020589113209464906
# epoch: 70, Train Loss: 0.013219, Train Acc: 0.995424, Test Loss: 4.485953, Test Acc: 0.678443
# epoch: 71, Train Loss: 0.011443, Train Acc: 0.995964, Test Loss: 4.457308, Test Acc: 0.683121
# epoch: 72, Train Loss: 0.011459, Train Acc: 0.995844, Test Loss: 4.634341, Test Acc: 0.680434
# epoch: 73, Train Loss: 0.011072, Train Acc: 0.996004, Test Loss: 4.703908, Test Acc: 0.684614
# epoch: 74, Train Loss: 0.012380, Train Acc: 0.995704, Test Loss: 4.726904, Test Acc: 0.680832
# lr is set to 0.00018530201888518417
# epoch: 75, Train Loss: 0.009988, Train Acc: 0.996324, Test Loss: 4.718746, Test Acc: 0.684216
# epoch: 76, Train Loss: 0.009625, Train Acc: 0.996483, Test Loss: 4.668997, Test Acc: 0.679240
# epoch: 77, Train Loss: 0.009522, Train Acc: 0.996663, Test Loss: 4.842018, Test Acc: 0.678443
# epoch: 78, Train Loss: 0.010544, Train Acc: 0.996204, Test Loss: 4.755687, Test Acc: 0.681728
# epoch: 79, Train Loss: 0.010053, Train Acc: 0.996503, Test Loss: 4.778548, Test Acc: 0.680732
# lr is set to 0.00016677181699666576
# epoch: 80, Train Loss: 0.009211, Train Acc: 0.996723, Test Loss: 4.728198, Test Acc: 0.682524
# epoch: 81, Train Loss: 0.008828, Train Acc: 0.996803, Test Loss: 4.752245, Test Acc: 0.684514
# epoch: 82, Train Loss: 0.009741, Train Acc: 0.996483, Test Loss: 4.789560, Test Acc: 0.683818
# epoch: 83, Train Loss: 0.009096, Train Acc: 0.996623, Test Loss: 4.867592, Test Acc: 0.681131
# epoch: 84, Train Loss: 0.009412, Train Acc: 0.996623, Test Loss: 4.798486, Test Acc: 0.686206
# lr is set to 0.0001500946352969992
# epoch: 85, Train Loss: 0.008375, Train Acc: 0.997063, Test Loss: 4.877239, Test Acc: 0.686505
# epoch: 86, Train Loss: 0.007090, Train Acc: 0.997402, Test Loss: 4.920106, Test Acc: 0.687600
# epoch: 87, Train Loss: 0.008846, Train Acc: 0.996723, Test Loss: 4.959602, Test Acc: 0.684713
# epoch: 88, Train Loss: 0.007968, Train Acc: 0.997063, Test Loss: 4.867611, Test Acc: 0.683619
# epoch: 89, Train Loss: 0.007338, Train Acc: 0.997363, Test Loss: 4.959406, Test Acc: 0.682126
# lr is set to 0.0001350851717672993
# epoch: 90, Train Loss: 0.007118, Train Acc: 0.997323, Test Loss: 4.935994, Test Acc: 0.682822
# epoch: 91, Train Loss: 0.007155, Train Acc: 0.997363, Test Loss: 4.989248, Test Acc: 0.686306
# epoch: 92, Train Loss: 0.007247, Train Acc: 0.997323, Test Loss: 4.995829, Test Acc: 0.684514
# epoch: 93, Train Loss: 0.007481, Train Acc: 0.997323, Test Loss: 4.950774, Test Acc: 0.687002
# epoch: 94, Train Loss: 0.006385, Train Acc: 0.997582, Test Loss: 5.089020, Test Acc: 0.682424
# lr is set to 0.00012157665459056936
# epoch: 95, Train Loss: 0.006982, Train Acc: 0.997442, Test Loss: 5.051116, Test Acc: 0.687699
# epoch: 96, Train Loss: 0.006316, Train Acc: 0.997602, Test Loss: 5.025285, Test Acc: 0.689789
# epoch: 97, Train Loss: 0.006274, Train Acc: 0.997622, Test Loss: 5.063318, Test Acc: 0.686206
# epoch: 98, Train Loss: 0.006298, Train Acc: 0.997582, Test Loss: 5.053081, Test Acc: 0.688694
# epoch: 99, Train Loss: 0.006770, Train Acc: 0.997462, Test Loss: 5.204634, Test Acc: 0.682225
# time used:  0:37:31.599379

# %%
# 测试模型在一个或数个batch的分类情况，并输出图像及对应预测名称，打印正确率
print('start testing')
#加载模型
model_test = torch.load('./model/model_momentum.ckpt')
#设置模型为评估模式
model_test.eval()
#设置测试集
mytest = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transforms.ToTensor(),download=True)
mytest_loader = torch.utils.data.DataLoader(mytest, batch_size=test_batch_size, shuffle=True)
#归一化
test_transform = transforms.Compose([
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    # transforms.ToPILImage()
])
eval_loss = 0
eval_acc = 0
fig = plt.figure()
#batch 循环
for i,(img,label) in enumerate(mytest_loader):
    img,label = img.to(device),label.to(device)
    test_img = img
    img = test_transform(img)
    out = model_test(img)
    loss = criterion(out,label)
    #记录误差
    eval_loss += loss.data.item()*label.size(0)
    #计算准确率
    _,pred = torch.max(out,1)
    num_correct = (pred == label).sum().item()
    eval_acc += num_correct

    #绘制图片（归一化后）
    if i == 0:
        for j in range(6):
            plt.subplot(2,3,j+1)
            plt.tight_layout()
            plt.imshow(test_img[j].permute(1,2,0), interpolation='none')
            plt.title('Prediction: {}'.format(classes[pred[j].item()]))
            plt.xticks([])
            plt.yticks([])
plt.show()
print('Test Loss: {:.6f}, Test Acc: {:.6f}'.format(eval_loss/len(mytest), eval_acc/len(mytest)))
# Out:
# start testing
# C:\Users\Darwin_\AppData\Local\Temp\ipykernel_17052\1821396629.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_test = torch.load('./model/model_momentum.ckpt')
# Files already downloaded and verified
# Test Loss: 5.204598, Test Acc: 0.682200
